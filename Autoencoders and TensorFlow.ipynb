# %%
import tensorflow as tf
import numpy as np
import random
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # 1. Autoencoder
#
# We have seen how to construct a simple neural network with one hidden layer that can successfully recognise handwritten digits. This network can be considered as an example of an encoder, which takes some high-dimensional input (in this case an image represented by a vector with 784 components) and encodes it into a lower-dimensional representation (a vector of 10 numbers which may be interpreted in terms of probabilities).

# %%
def sigmoid(z):
    """The sigmoid function."""
    return 1.0/(1.0+np.exp(-z))

def sigmoid_prime(z):
    """Derivative of the sigmoid function."""
    return sigmoid(z)*(1-sigmoid(z))

# %%
class Network(object):

    def __init__(self, sizes):
        """The list ``sizes`` contains the number of neurons in the
        respective layers of the network.  For example, if the list
        was [2, 3, 1] then it would be a three-layer network, with the
        first layer containing 2 neurons, the second layer 3 neurons,
        and the third layer 1 neuron.  The biases and weights for the
        network are initialized randomly, using a Gaussian
        distribution with mean 0, and variance 1.  Note that the first
        layer is assumed to be an input layer, and by convention we
        won't set any biases for those neurons, since biases are only
        ever used in computing the outputs from later layers."""
        self.num_layers = len(sizes)
        self.sizes = sizes
        self.biases = [np.random.randn(y, 1) for y in sizes[1:]]
        self.weights = [np.random.randn(y, x)
                        for x, y in zip(sizes[:-1], sizes[1:])]

    def feedforward(self, a):
        """Return the output of the network if ``a`` is input."""
        for b, w in zip(self.biases, self.weights):
            a = sigmoid(np.dot(w, a)+b)
        return a

    def SGD(self, training_data, epochs, mini_batch_size, eta,
            test_data=None):
        """Train the neural network using mini-batch stochastic
        gradient descent.  The ``training_data`` is a list of tuples
        ``(x, y)`` representing the training inputs and the desired
        outputs.  The other non-optional parameters are
        self-explanatory.  If ``test_data`` is provided then the
        network will be evaluated against the test data after each
        epoch, and partial progress printed out.  This is useful for
        tracking progress, but slows things down substantially."""

        training_data = list(training_data)
        n = len(training_data)

        if test_data:
            test_data = list(test_data)
            n_test = len(test_data)

        for j in range(epochs):
            random.shuffle(training_data)
            mini_batches = [
                training_data[k:k+mini_batch_size]
                for k in range(0, n, mini_batch_size)]
            for mini_batch in mini_batches:
                self.update_mini_batch(mini_batch, eta)
            if test_data:
                print("Epoch {} : {} / {}".format(j,self.evaluate(test_data),n_test));
            else:
                print("Epoch {} complete".format(j))

    def update_mini_batch(self, mini_batch, eta):
        """Update the network's weights and biases by applying
        gradient descent using backpropagation to a single mini batch.
        The ``mini_batch`` is a list of tuples ``(x, y)``, and ``eta``
        is the learning rate."""
        nabla_b = [np.zeros(b.shape) for b in self.biases]
        nabla_w = [np.zeros(w.shape) for w in self.weights]
        for x, y in mini_batch:
            delta_nabla_b, delta_nabla_w = self.backprop(x, y)
            nabla_b = [nb+dnb for nb, dnb in zip(nabla_b, delta_nabla_b)]
            nabla_w = [nw+dnw for nw, dnw in zip(nabla_w, delta_nabla_w)]
        self.weights = [w-(eta/len(mini_batch))*nw
                        for w, nw in zip(self.weights, nabla_w)]
        self.biases = [b-(eta/len(mini_batch))*nb
                       for b, nb in zip(self.biases, nabla_b)]

    def backprop(self, x, y):
        """Return a tuple ``(nabla_b, nabla_w)`` representing the
        gradient for the cost function C_x.  ``nabla_b`` and
        ``nabla_w`` are layer-by-layer lists of numpy arrays, similar
        to ``self.biases`` and ``self.weights``."""
        nabla_b = [np.zeros(b.shape) for b in self.biases]
        nabla_w = [np.zeros(w.shape) for w in self.weights]
        # feedforward
        activation = x
        activations = [x] # list to store all the activations, layer by layer
        zs = [] # list to store all the z vectors, layer by layer
        for b, w in zip(self.biases, self.weights):
            z = np.dot(w, activation)+b
            zs.append(z)
            activation = sigmoid(z)
            activations.append(activation)
        # backward pass
        delta = self.cost_derivative(activations[-1], y) * \
            sigmoid_prime(zs[-1])
        nabla_b[-1] = delta
        nabla_w[-1] = np.dot(delta, activations[-2].transpose())
        # Note that the variable l in the loop below is used a little
        # differently to the notation in Chapter 2 of the book.  Here,
        # l = 1 means the last layer of neurons, l = 2 is the
        # second-last layer, and so on.  It's a renumbering of the
        # scheme in the book, used here to take advantage of the fact
        # that Python can use negative indices in lists.
        for l in range(2, self.num_layers):
            z = zs[-l]
            sp = sigmoid_prime(z)
            delta = np.dot(self.weights[-l+1].transpose(), delta) * sp
            nabla_b[-l] = delta
            nabla_w[-l] = np.dot(delta, activations[-l-1].transpose())
        return (nabla_b, nabla_w)

    def evaluate(self, test_data):
        """Return the number of test inputs for which the neural
        network outputs the correct result. Note that the neural
        network's output is assumed to be the index of whichever
        neuron in the final layer has the highest activation."""
        test_results = [(np.argmax(self.feedforward(x)), y)
                        for (x, y) in test_data]
        return sum(int(x == y) for (x, y) in test_results)

    def cost_derivative(self, output_activations, y):
        """Return the vector of partial derivatives \\partial C_x /
        \\partial a for the output activations."""
        return (output_activations-y)

# %%
import mnist_loader

def plot_digit(digit):
    # A function to plot a vector of length 784 as a 28 x 28 image
    digit_image = digit.reshape(28,28)
    plt.imshow(digit_image, cmap = plt.get_cmap('gray'))
    plt.axis("off")
    plt.show()

# %% [markdown]
# ## 1.1 Encoder
#
# Construct and train an encoder, a network that takes in a vector of 784 numbers and produces a vector of 10 numbers. Your network should have no hidden layers.

# %%
encoder = Network([784, 10])

training_data, validation_data, test_data = mnist_loader.load_data_wrapper()
# Make lists as they are zip and once opne, it changes its state
training_data = list(training_data)
validation_data = list(validation_data)
test_data = list(test_data)

# %%
encoder.SGD(training_data, 10, 10, 3.0, test_data=test_data)
# Out:
# Epoch 0 : 7372 / 10000
# Epoch 1 : 7427 / 10000
# Epoch 2 : 7455 / 10000
# Epoch 3 : 7448 / 10000
# Epoch 4 : 7456 / 10000
# Epoch 5 : 7481 / 10000
# Epoch 6 : 7499 / 10000
# Epoch 7 : 7487 / 10000
# Epoch 8 : 7470 / 10000
# Epoch 9 : 7501 / 10000

# %% [markdown]
# ## 1.2 Decoder
#
# Construct and train a corresponding decoder, a network that does the reverse of this process. The decoder should take a vector of 10 numbers and reconstruct a vector with 784 numbers representing an image of a handwritten digit.

# %%
decoder = Network([10, 784])

# %%
training_data_inv = []

for x, y in training_data:
  training_data_inv.append((y, x))

# %%
decoder.SGD(training_data_inv, 10, 10, 3.0)
# Out:
# Epoch 0 complete
# Epoch 1 complete
# Epoch 2 complete
# Epoch 3 complete
# Epoch 4 complete
# Epoch 5 complete
# Epoch 6 complete
# Epoch 7 complete
# Epoch 8 complete
# Epoch 9 complete

# %% [markdown]
# Since the decoder goes from number 0-9 to image of digit, the weights indicate how important it is for that number that the pixel it is pointing to is filled up for a proper representation of the digit.

# %% [markdown]
# Use your decoder to produce a set of 10 images, one for each “perfect” example of a digit. Here, perfect means the input vector only has one non-zero entry and it is equal to 1.

# %%
for i in range(10):
  one_hot = np.eye(10)[i].reshape(10, 1) # Reshape one_hot to be a column vector (10, 1)

  image = decoder.feedforward(one_hot)
  plot_digit(image)

# %% [markdown]
# ## 1.3 Autoencoder
#
# Combine the two networks to produce an autoencoder, which takes an input vector of 784 components and produces an output vector with 784 components.

# %%
def autoencoder_feedforward(input):
    encoded = encoder.feedforward(input)
    decoded = decoder.feedforward(encoded)
    return decoded

# %%
encoder.feedforward(validation_data[0][0])
# Out:
# array([[4.86612553e-17],
#        [3.07362998e-06],
#        [3.79766811e-04],
#        [3.63171208e-11],
#        [7.47148682e-18],
#        [2.77684923e-05],
#        [3.02344766e-12],
#        [1.53359756e-22],
#        [5.71255432e-11],
#        [1.16257119e-26]])

# %% [markdown]
# Test your autoencoder with a sample of 10 digits from the validation set. Include 5 cases where the encoder correctly predicts the expected output and 5 cases where it does not.

# %%
validation_data[0][1]
# Out:
# np.int64(3)

# %%
correct_count, incorrect_count = 0, 0

for x, y in validation_data:
  if np.argmax(encoder.feedforward(x)) == y and correct_count<5:
    correct_count += 1
    plot_digit(x)
    plot_digit(autoencoder_feedforward(x))
    print(f"Was: {y}, Guessed:{np.argmax(encoder.feedforward(x))}")

  elif np.argmax(encoder.feedforward(x)) != y and incorrect_count<5:
    incorrect_count += 1
    plot_digit(x)
    plot_digit(autoencoder_feedforward(x))
    print(f"Was: {y}, Guessed:{np.argmax(encoder.feedforward(x))}")

  #plot_digit(autoencoder_feedforward(x))
  if correct_count + incorrect_count == 10: break
# Out:
# Was: 3, Guessed:2
# Was: 8, Guessed:5
# Was: 6, Guessed:6
# Was: 9, Guessed:9
# Was: 6, Guessed:6
# Was: 4, Guessed:4
# Was: 5, Guessed:5
# Was: 3, Guessed:5
# Was: 8, Guessed:5
# Was: 5, Guessed:4

# %% [markdown]
# ## 1.4 A 40-neuron hidden layer autoencoder
#
# Produce another autoencoder as before, completing the steps above, but include a hidden layer with 40 neurons in both the encoder and decoder.

# %%
# a)
encoder = Network([784, 40, 10])
training_data, validation_data, test_data = mnist_loader.load_data_wrapper()
# Make lists as they are zip and once opne, it changes its state
training_data = list(training_data)
validation_data = list(validation_data)
test_data = list(test_data)

encoder.SGD(training_data, 10, 10, 0.5, test_data=test_data)
# Out:
# Epoch 0 : 7250 / 10000
# Epoch 1 : 8724 / 10000
# Epoch 2 : 8973 / 10000
# Epoch 3 : 9105 / 10000
# Epoch 4 : 9164 / 10000
# Epoch 5 : 9236 / 10000
# Epoch 6 : 9265 / 10000
# Epoch 7 : 9294 / 10000
# Epoch 8 : 9326 / 10000
# Epoch 9 : 9336 / 10000

# %%
# b)
decoder = Network([10, 40, 784])

training_data_inv = []
for x, y in training_data:
  training_data_inv.append((y, x))

decoder.SGD(training_data_inv, 10, 10, 3.0)
# Out:
# Epoch 0 complete
# Epoch 1 complete
# Epoch 2 complete
# Epoch 3 complete
# Epoch 4 complete
# Epoch 5 complete
# Epoch 6 complete
# Epoch 7 complete
# Epoch 8 complete
# Epoch 9 complete

# %%
# d)
for i in range(10):
  one_hot = np.eye(10)[i].reshape(10, 1) # Reshape one_hot to be a column vector (10, 1)
  image = decoder.feedforward(one_hot)
  plot_digit(image)

# %%
#e)
def autoencoder_feedforward(input):
    encoded = encoder.feedforward(input)
    decoded = decoder.feedforward(encoded)
    return decoded

# %%
#f)
correct_count, incorrect_count = 0, 0

for x, y in validation_data:
  if np.argmax(encoder.feedforward(x)) == y and correct_count<5:
    correct_count += 1
    plot_digit(x)
    plot_digit(autoencoder_feedforward(x))
    print(f"Was: {y}, Guessed:{np.argmax(encoder.feedforward(x))}")

  elif np.argmax(encoder.feedforward(x)) != y and incorrect_count<5:
    incorrect_count += 1
    plot_digit(x)
    plot_digit(autoencoder_feedforward(x))
    print(f"Was: {y}, Guessed:{np.argmax(encoder.feedforward(x))}")

  #plot_digit(autoencoder_feedforward(x))
  if correct_count + incorrect_count == 10: break
# Out:
# Was: 3, Guessed:3
# Was: 8, Guessed:8
# Was: 6, Guessed:6
# Was: 9, Guessed:9
# Was: 6, Guessed:6
# Was: 4, Guessed:2
# Was: 3, Guessed:6
# Was: 3, Guessed:5
# Was: 2, Guessed:6
# Was: 9, Guessed:5

# %% [markdown]
# # 2. Training a neural network with TensorFlow and Keras
#
# You wish to produce neural networks that approximate the functions
# $$f(x) = sin\, x \\ g(x) = (1+sin\, x)/2$$

# %% [markdown]
# ## 2.1 Training data
#
# Create training data by evaluating $f(x)$ and $g(x)$ at 10,000 equally-spaced points in the range $x ∈[0,2π]$.

# %%
x = np.linspace(0, 2*np.pi, 10000)
fx = np.sin(x)
gx = (1 + np.sin(x)) / 2

# %% [markdown]
# ## 2.2 Architecture
#
# Using TensorFlow and Keras, construct neural networks for the two functions with the following properties:
#
# • An input layer with a single neuron.
#
# • A hidden layer with 3 neurons and a logistic sigmoid activation function.
#
# • An output layer with a single neuron and a logistic sigmoid activation function.

# %%
fmodel = tf.keras.models.Sequential([
  tf.keras.layers.Input(shape=(1,)),
  tf.keras.layers.Dense(3, activation='sigmoid'),
  tf.keras.layers.Dense(1, activation='sigmoid')
])

gmodel = tf.keras.models.clone_model(fmodel)

# %% [markdown]
# ## 2.3 Training
#
# Train your networks using the training data you produced. Use the following parameters for training:
#
# • A mean squared error cost function.
#
# • Batch size 20.
#
# • 200 epochs.

# %%
fmodel.compile(optimizer='adam',
              loss="mean_squared_error")

fmodel.fit(x, fx, epochs=200, batch_size=20)
# Out:
# Epoch 1/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.5369
# Epoch 2/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.4748
# Epoch 3/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4550
# Epoch 4/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4214
# Epoch 5/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3971
# Epoch 6/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.3630
# Epoch 7/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.3387
# Epoch 8/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.3376
# Epoch 9/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3213
# Epoch 10/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3179
# Epoch 11/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.3138
# Epoch 12/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.3114
# Epoch 13/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.3048
# Epoch 14/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2979
# Epoch 15/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.3062
# Epoch 16/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2994
# Epoch 17/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2975
# Epoch 18/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2965
# Epoch 19/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2987
# Epoch 20/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3011
# Epoch 21/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2973
# Epoch 22/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2883
# Epoch 23/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2882
# Epoch 24/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2898
# Epoch 25/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2895
# Epoch 26/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2887
# Epoch 27/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2818
# Epoch 28/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2929
# Epoch 29/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2895
# Epoch 30/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2839
# Epoch 31/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.2800
# Epoch 32/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.2853
# Epoch 33/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2827
# Epoch 34/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2845
# Epoch 35/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2858
# Epoch 36/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2832
# Epoch 37/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2853
# Epoch 38/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2774
# Epoch 39/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2791
# Epoch 40/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2682
# Epoch 41/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2633
# Epoch 42/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2641
# Epoch 43/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2601
# Epoch 44/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2534
# Epoch 45/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2504
# Epoch 46/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2509
# Epoch 47/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2560
# Epoch 48/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2488
# Epoch 49/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2523
# Epoch 50/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2518
# Epoch 51/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2565
# Epoch 52/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2499
# Epoch 53/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2540
# Epoch 54/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2509
# Epoch 55/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2534
# Epoch 56/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2479
# Epoch 57/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2502
# Epoch 58/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2522
# Epoch 59/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2558
# Epoch 60/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2475
# Epoch 61/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2545
# Epoch 62/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2526
# Epoch 63/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2475
# Epoch 64/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2590
# Epoch 65/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2543
# Epoch 66/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2496
# Epoch 67/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2515
# Epoch 68/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2468
# Epoch 69/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2471
# Epoch 70/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2523
# Epoch 71/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2549
# Epoch 72/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2553
# Epoch 73/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2504
# Epoch 74/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2515
# Epoch 75/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2525
# Epoch 76/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2540
# Epoch 77/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2522
# Epoch 78/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2565
# Epoch 79/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2514
# Epoch 80/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2498
# Epoch 81/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2527
# Epoch 82/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2510
# Epoch 83/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2456
# Epoch 84/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2489
# Epoch 85/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2555
# Epoch 86/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2543
# Epoch 87/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2524
# Epoch 88/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2513
# Epoch 89/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2489
# Epoch 90/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2525
# Epoch 91/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2460
# Epoch 92/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2483
# Epoch 93/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2476
# Epoch 94/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2506
# Epoch 95/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2484
# Epoch 96/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2537
# Epoch 97/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2500
# Epoch 98/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2530
# Epoch 99/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2569
# Epoch 100/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2560
# Epoch 101/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2498
# Epoch 102/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2545
# Epoch 103/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2563
# Epoch 104/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2498
# Epoch 105/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2574
# Epoch 106/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2486
# Epoch 107/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2481
# Epoch 108/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2505
# Epoch 109/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2547
# Epoch 110/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2536
# Epoch 111/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2497
# Epoch 112/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2527
# Epoch 113/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2577
# Epoch 114/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2488
# Epoch 115/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2521
# Epoch 116/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2555
# Epoch 117/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2473
# Epoch 118/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2543
# Epoch 119/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2512
# Epoch 120/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2526
# Epoch 121/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2475
# Epoch 122/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2556
# Epoch 123/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2458
# Epoch 124/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2477
# Epoch 125/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2552
# Epoch 126/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2499
# Epoch 127/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2494
# Epoch 128/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2510
# Epoch 129/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2501
# Epoch 130/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2526
# Epoch 131/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2539
# Epoch 132/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2479
# Epoch 133/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2510
# Epoch 134/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2522
# Epoch 135/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2484
# Epoch 136/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2524
# Epoch 137/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2503
# Epoch 138/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2515
# Epoch 139/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2454
# Epoch 140/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2575
# Epoch 141/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2491
# Epoch 142/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2535
# Epoch 143/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2514
# Epoch 144/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2487
# Epoch 145/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2506
# Epoch 146/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2512
# Epoch 147/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2533
# Epoch 148/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2519
# Epoch 149/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2492
# Epoch 150/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2535
# Epoch 151/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2478
# Epoch 152/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2543
# Epoch 153/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2534
# Epoch 154/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2513
# Epoch 155/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2524
# Epoch 156/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2551
# Epoch 157/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2497
# Epoch 158/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2534
# Epoch 159/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2561
# Epoch 160/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2498
# Epoch 161/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2503
# Epoch 162/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2516
# Epoch 163/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2481
# Epoch 164/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2529
# Epoch 165/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2483
# Epoch 166/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2549
# Epoch 167/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2530
# Epoch 168/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2510
# Epoch 169/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2457
# Epoch 170/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2533
# Epoch 171/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2528
# Epoch 172/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2515
# Epoch 173/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2490
# Epoch 174/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2518
# Epoch 175/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2541
# Epoch 176/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2502
# Epoch 177/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2532
# Epoch 178/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2508
# Epoch 179/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2493
# Epoch 180/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2542
# Epoch 181/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2491
# Epoch 182/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2526
# Epoch 183/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2504
# Epoch 184/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2476
# Epoch 185/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2473
# Epoch 186/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2533
# Epoch 187/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2529
# Epoch 188/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2558
# Epoch 189/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2567
# Epoch 190/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2498
# Epoch 191/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2507
# Epoch 192/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2454
# Epoch 193/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2559
# Epoch 194/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2556
# Epoch 195/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2480
# Epoch 196/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2465
# Epoch 197/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2582
# Epoch 198/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2436
# Epoch 199/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2444
# Epoch 200/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2530

# %%
gmodel.compile(optimizer='adam',
              loss="mean_squared_error")

gmodel.fit(x, gx, epochs=200, batch_size=20)
# Out:
# Epoch 1/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.1527
# Epoch 2/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0843
# Epoch 3/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0603
# Epoch 4/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0461
# Epoch 5/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0378
# Epoch 6/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0322
# Epoch 7/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0285
# Epoch 8/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0266
# Epoch 9/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0253
# Epoch 10/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0249
# Epoch 11/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0232
# Epoch 12/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0227
# Epoch 13/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0216
# Epoch 14/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0213
# Epoch 15/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0213
# Epoch 16/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0195
# Epoch 17/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0177
# Epoch 18/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0171
# Epoch 19/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0153
# Epoch 20/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0135
# Epoch 21/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0122
# Epoch 22/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0109
# Epoch 23/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0108
# Epoch 24/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0105
# Epoch 25/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0097
# Epoch 26/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0096
# Epoch 27/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0097
# Epoch 28/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092
# Epoch 29/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092
# Epoch 30/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0089
# Epoch 31/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0088
# Epoch 32/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0091
# Epoch 33/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0087
# Epoch 34/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0089
# Epoch 35/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0090
# Epoch 36/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0090
# Epoch 37/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0086
# Epoch 38/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0089
# Epoch 39/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0088
# Epoch 40/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0085
# Epoch 41/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0088
# Epoch 42/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0088
# Epoch 43/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0087
# Epoch 44/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0086
# Epoch 45/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0088
# Epoch 46/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0088
# Epoch 47/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0087
# Epoch 48/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0087
# Epoch 49/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0086
# Epoch 50/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0090
# Epoch 51/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0085
# Epoch 52/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0084
# Epoch 53/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0086
# Epoch 54/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0085
# Epoch 55/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0086
# Epoch 56/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0085
# Epoch 57/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0090
# Epoch 58/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0088
# Epoch 59/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0089
# Epoch 60/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0086
# Epoch 61/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0085
# Epoch 62/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0085
# Epoch 63/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0087
# Epoch 64/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0084
# Epoch 65/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0083
# Epoch 66/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0086
# Epoch 67/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0087
# Epoch 68/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0084
# Epoch 69/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0083
# Epoch 70/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0086
# Epoch 71/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0086
# Epoch 72/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0081
# Epoch 73/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0081
# Epoch 74/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0084
# Epoch 75/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0086
# Epoch 76/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0082
# Epoch 77/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0082
# Epoch 78/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0085
# Epoch 79/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0084
# Epoch 80/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0083
# Epoch 81/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0083
# Epoch 82/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0084
# Epoch 83/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0083
# Epoch 84/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0083
# Epoch 85/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0082
# Epoch 86/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0083
# Epoch 87/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0084
# Epoch 88/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0083
# Epoch 89/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0080
# Epoch 90/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0083
# Epoch 91/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0084
# Epoch 92/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0083
# Epoch 93/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0086
# Epoch 94/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0083
# Epoch 95/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0083
# Epoch 96/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0081
# Epoch 97/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0082
# Epoch 98/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0083
# Epoch 99/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0084
# Epoch 100/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0084
# Epoch 101/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0082
# Epoch 102/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0082
# Epoch 103/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0081
# Epoch 104/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0082
# Epoch 105/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0081
# Epoch 106/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0078
# Epoch 107/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0082
# Epoch 108/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0081
# Epoch 109/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0079
# Epoch 110/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0081
# Epoch 111/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0083
# Epoch 112/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0082
# Epoch 113/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0077
# Epoch 114/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0081
# Epoch 115/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0082
# Epoch 116/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0082
# Epoch 117/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0081
# Epoch 118/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0082
# Epoch 119/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0080
# Epoch 120/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0081
# Epoch 121/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0078
# Epoch 122/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0079
# Epoch 123/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0082
# Epoch 124/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0079
# Epoch 125/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0084
# Epoch 126/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0082
# Epoch 127/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0081
# Epoch 128/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0080
# Epoch 129/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0079
# Epoch 130/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0080
# Epoch 131/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0076
# Epoch 132/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0077
# Epoch 133/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0084
# Epoch 134/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0077
# Epoch 135/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0083
# Epoch 136/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0079
# Epoch 137/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0080
# Epoch 138/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0083
# Epoch 139/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0081
# Epoch 140/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0080
# Epoch 141/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0078
# Epoch 142/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0079
# Epoch 143/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0078
# Epoch 144/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0079
# Epoch 145/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0079
# Epoch 146/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0081
# Epoch 147/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0081
# Epoch 148/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0084
# Epoch 149/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0077
# Epoch 150/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0080
# Epoch 151/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0080
# Epoch 152/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0081
# Epoch 153/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0082
# Epoch 154/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0081
# Epoch 155/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0079
# Epoch 156/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0080
# Epoch 157/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0086
# Epoch 158/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0079
# Epoch 159/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0079
# Epoch 160/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0079
# Epoch 161/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0081
# Epoch 162/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0080
# Epoch 163/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0078
# Epoch 164/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0079
# Epoch 165/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0081
# Epoch 166/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0082
# Epoch 167/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0080
# Epoch 168/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0082
# Epoch 169/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0078
# Epoch 170/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0079
# Epoch 171/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0083
# Epoch 172/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0084
# Epoch 173/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0083
# Epoch 174/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0082
# Epoch 175/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0080
# Epoch 176/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0080
# Epoch 177/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0078
# Epoch 178/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0080
# Epoch 179/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0080
# Epoch 180/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0079
# Epoch 181/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0080
# Epoch 182/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0078
# Epoch 183/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0080
# Epoch 184/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0078
# Epoch 185/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0077
# Epoch 186/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0078
# Epoch 187/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0078
# Epoch 188/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0077
# Epoch 189/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0081
# Epoch 190/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0078
# Epoch 191/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0077
# Epoch 192/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0081
# Epoch 193/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0081
# Epoch 194/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0075
# Epoch 195/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0079
# Epoch 196/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0080
# Epoch 197/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0080
# Epoch 198/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0083
# Epoch 199/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0080
# Epoch 200/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0079

# %%
fmodel.save("/content/drive/MyDrive/4th year/MoML/fmodel.keras")
gmodel.save("/content/drive/MyDrive/4th year/MoML/gmodel.keras")

# %% [markdown]
# ## 2.4 Comparison
#
# Produce a plot comparing your models against the true functions $f (x)$ and $g(x)$ over the range $x ∈[0,2π]$. Comment on if one model performs better than the other, and why.

# %%
fnet = fmodel.predict(x)
gnet = gmodel.predict(x)

plt.plot(x/np.pi, fx, label ='f(x)')
plt.plot(x/np.pi, fnet, label='fnet(x)')
plt.xlabel('x ($\\pi$)')
plt.ylabel('y')
plt.legend()
plt.show()

plt.plot(x/np.pi, gx, label ='g(x)')
plt.plot(x/np.pi, gnet, label='gnet(x)')
plt.xlabel('x ($\\pi$)')
plt.ylabel('y')
plt.legend()
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %% [markdown]
# Both models seem similarly accurate up until $\pi$ but after that, `gnet(x)` is clearly more accurate as `sigmoid` cannot return negative values making `fnet(x)`0 after that. This could be solved like this:

# %%
def shifted_sigmoid(x):
    return 2 * 1.0/(1.0+tf.exp(-x)) - 1

# Model
fmodel_ = tf.keras.models.Sequential([
  tf.keras.layers.Input(shape=(1,)),
  tf.keras.layers.Dense(3, activation='sigmoid'),
  tf.keras.layers.Dense(1, activation=shifted_sigmoid)
])

# Train
fmodel_.compile(optimizer='adam',
              loss="mean_squared_error")
fmodel_.fit(x, fx, epochs=200, batch_size=20)

# Predict
fnet = fmodel_.predict(x)
plt.plot(x/np.pi, fx, label ='f(x)')
plt.plot(x/np.pi, fnet, label='fnet(x)')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
# Out:
# Epoch 1/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.5276
# Epoch 2/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4076
# Epoch 3/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.3137
# Epoch 4/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2424
# Epoch 5/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.1842
# Epoch 6/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.1483
# Epoch 7/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1270
# Epoch 8/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1132
# Epoch 9/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1010
# Epoch 10/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0925
# Epoch 11/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0836
# Epoch 12/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0716
# Epoch 13/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0599
# Epoch 14/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0514
# Epoch 15/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0470
# Epoch 16/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0420
# Epoch 17/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0407
# Epoch 18/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0387
# Epoch 19/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0388
# Epoch 20/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0355
# Epoch 21/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0378
# Epoch 22/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0371
# Epoch 23/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0358
# Epoch 24/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0361
# Epoch 25/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0352
# Epoch 26/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0358
# Epoch 27/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0364
# Epoch 28/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0350
# Epoch 29/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0361
# Epoch 30/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0358
# Epoch 31/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0337
# Epoch 32/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0359
# Epoch 33/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0348
# Epoch 34/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0356
# Epoch 35/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0351
# Epoch 36/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0349
# Epoch 37/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0361
# Epoch 38/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0356
# Epoch 39/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0345
# Epoch 40/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0358
# Epoch 41/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0350
# Epoch 42/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0350
# Epoch 43/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0351
# Epoch 44/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0347
# Epoch 45/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0361
# Epoch 46/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0350
# Epoch 47/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0345
# Epoch 48/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0351
# Epoch 49/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0345
# Epoch 50/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0346
# Epoch 51/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0349
# Epoch 52/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0348
# Epoch 53/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0347
# Epoch 54/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0364
# Epoch 55/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0347
# Epoch 56/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0357
# Epoch 57/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0341
# Epoch 58/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0344
# Epoch 59/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0341
# Epoch 60/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0349
# Epoch 61/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0335
# Epoch 62/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0355
# Epoch 63/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0340
# Epoch 64/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0333
# Epoch 65/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0338
# Epoch 66/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0331
# Epoch 67/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0352
# Epoch 68/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0351
# Epoch 69/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0345
# Epoch 70/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0341
# Epoch 71/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.0341
# Epoch 72/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0326
# Epoch 73/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0336
# Epoch 74/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0338
# Epoch 75/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0338
# Epoch 76/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0343
# Epoch 77/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0344
# Epoch 78/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0339
# Epoch 79/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0324
# Epoch 80/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0340
# Epoch 81/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0334
# Epoch 82/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0340
# Epoch 83/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0324
# Epoch 84/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0335
# Epoch 85/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0336
# Epoch 86/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0342
# Epoch 87/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0325
# Epoch 88/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0318
# Epoch 89/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0324
# Epoch 90/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0329
# Epoch 91/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0337
# Epoch 92/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0326
# Epoch 93/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0325
# Epoch 94/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0336
# Epoch 95/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0328
# Epoch 96/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0329
# Epoch 97/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0330
# Epoch 98/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0323
# Epoch 99/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0332
# Epoch 100/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0308
# Epoch 101/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0325
# Epoch 102/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0321
# Epoch 103/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0332
# Epoch 104/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0327
# Epoch 105/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0331
# Epoch 106/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0323
# Epoch 107/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0316
# Epoch 108/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0324
# Epoch 109/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0333
# Epoch 110/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0324
# Epoch 111/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0329
# Epoch 112/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0315
# Epoch 113/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0323
# Epoch 114/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0321
# Epoch 115/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0320
# Epoch 116/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0321
# Epoch 117/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0314
# Epoch 118/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0341
# Epoch 119/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0330
# Epoch 120/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0315
# Epoch 121/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0322
# Epoch 122/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0316
# Epoch 123/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0316
# Epoch 124/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0327
# Epoch 125/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0323
# Epoch 126/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0320
# Epoch 127/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0317
# Epoch 128/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0329
# Epoch 129/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0309
# Epoch 130/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0322
# Epoch 131/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0318
# Epoch 132/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0307
# Epoch 133/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0316
# Epoch 134/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0325
# Epoch 135/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0324
# Epoch 136/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0311
# Epoch 137/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0302
# Epoch 138/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0333
# Epoch 139/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0324
# Epoch 140/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0325
# Epoch 141/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0314
# Epoch 142/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0333
# Epoch 143/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0320
# Epoch 144/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0316
# Epoch 145/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0321
# Epoch 146/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0315
# Epoch 147/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0315
# Epoch 148/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0319
# Epoch 149/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0308
# Epoch 150/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0309
# Epoch 151/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0339
# Epoch 152/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0322
# Epoch 153/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0315
# Epoch 154/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0323
# Epoch 155/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0314
# Epoch 156/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0301
# Epoch 157/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0310
# Epoch 158/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0312
# Epoch 159/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0313
# Epoch 160/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0321
# Epoch 161/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0313
# Epoch 162/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0318
# Epoch 163/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0328
# Epoch 164/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0318
# Epoch 165/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0332
# Epoch 166/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0312
# Epoch 167/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0318
# Epoch 168/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0308
# Epoch 169/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0322
# Epoch 170/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0323
# Epoch 171/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0322
# Epoch 172/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0321
# Epoch 173/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0319
# Epoch 174/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0309
# Epoch 175/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0303
# Epoch 176/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0314
# Epoch 177/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0305
# Epoch 178/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0330
# Epoch 179/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0311
# Epoch 180/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0306
# Epoch 181/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0313
# Epoch 182/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0303
# Epoch 183/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0318
# Epoch 184/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0313
# Epoch 185/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0316
# Epoch 186/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0299
# Epoch 187/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0308
# Epoch 188/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0310
# Epoch 189/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0313
# Epoch 190/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0298
# Epoch 191/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0281
# Epoch 192/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0291
# Epoch 193/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0288
# Epoch 194/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0291
# Epoch 195/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0269
# Epoch 196/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0268
# Epoch 197/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0269
# Epoch 198/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0265
# Epoch 199/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0248
# Epoch 200/200
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0253
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %% [markdown]
# Notice how the shape of the output is essentially the same as for `gnet(x)` since they are esentially the same function just shifted. Small changes might happen due to the retrainning of the network.

# %% [markdown]
# ## 2.5 Evaluation on un-seen data
#
# Plot your model for $g(x)$ over the range $x ∈[0,4π]$. Comment on and give an explanation for the performance of your model in this case. Your comment should include two possible explanations based on (i) the training data used and (ii) the expressivity of a network with three hidden neurons.

# %%
gx2 = (1 + np.sin(2*x)) / 2

plt.plot(2*x/np.pi, gx2, label ='g(x)')
plt.plot(2*x/np.pi, gmodel.predict(2*x), label='gnet(x)')

plt.xlabel('x ($\pi$)')
plt.ylabel('y')
plt.legend()
plt.show()
# Out:
#  78/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# <>:6: SyntaxWarning: invalid escape sequence '\p'
# <>:6: SyntaxWarning: invalid escape sequence '\p'
# /tmp/ipython-input-864983077.py:6: SyntaxWarning: invalid escape sequence '\p'
#   plt.xlabel('x ($\pi$)')
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %% [markdown]
# The model essentially fails at the same time as before diverging from the solution as it does not know that it is periodical with a period of $2\pi$. This could be saved with (i) larger data covering at least 2 periods and/or (ii) more neurons in the hidden layer, 3 neurons implies only 3 'bumps' to model the function.
